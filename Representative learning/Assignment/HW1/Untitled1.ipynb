# %%
import xlsxwriter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel ('sample_stock_data.xlsx') 
df = np.array(df)
# Create a Pandas dataframe from the data.
df = pd.DataFrame(df.T)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('sample_stock_data1.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
df = pd.read_excel ('sample_stock_data1.xlsx') 
print(df)
print(df.shape[1])
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  4.054688  4.085938  4.039063  4.000000  4.046875  4.007813
# 1           1  4.093750  4.085938  4.039063  4.054688  4.062500  4.054688
#
#           6         7         8  ...      9988      9989      9990      9991  \
# 0  4.046875  4.046875  4.093750  ...  1.672840  1.648148  1.629630  1.635803
# 1  4.078125  4.093750  4.179688  ...  1.691358  1.648148  1.654321  1.679012
#
#        9992      9993      9994      9995      9996      9997
# 0  1.672840  1.611111  1.586420  1.580247  1.623457  1.629630
# 1  1.679012  1.635803  1.598765  1.660494  1.654321  1.641975
#
# [2 rows x 9999 columns]
# 9999

# %%
aa = np.array(df)
print(aa)
# Out:
# [[0.       4.054688 4.085938 ... 1.580247 1.623457 1.62963 ]
#  [1.       4.09375  4.085938 ... 1.660494 1.654321 1.641975]]

# %%
aa = (aa[:,1:df.shape[1]])
aa = aa
print(aa.shape)
# Out:
# (2, 9998)

# %%
plt.figure(figsize=(20, 10))
fig, ax = plt.subplots(num=1, clear=True)
handle = ax.plot(aa[0,:], aa[1,:], '.')

# %%
print(np.random.randint(2,4))
# Out:
# 2
