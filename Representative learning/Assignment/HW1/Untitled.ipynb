# %%
from scipy.stats import multivariate_normal as mult_gauss
import numpy as np
import random
from numpy import linalg as LA
import sklearn as sklearn
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib qt

# %%
generators = [
    mult_gauss([10, 1], [[1, 0], [0, 1]]),             
    mult_gauss([20, 0], [[2, 0], [0, 3]]), 
    mult_gauss([-1, -1], [[5, 0], [0, 5]])]

# %%
draw = np.random.choice([0, 1, 2], 10000, p=[0.7, 0.2, 0.1])
unique, counts = np.unique(draw, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 7036, 1: 1942, 2: 1022}

# %%
X_Data = [np.array(generators[i].rvs()) for i in draw]
X_Data = np.array(X_Data)
print(X_Data)
print(X_Data.shape)
# X_Data = X_Data.T
# print(X_Data[:,0])
# print(X_Data[:,1])
# Out:
# [[ 9.43166136  2.05393983]
#  [18.22462182 -2.83036489]
#  [11.71165396  1.92840934]
#  ...
#  [19.19258687 -2.6218883 ]
#  [10.03777716  1.60202255]
#  [10.55083177  0.24162516]]
# (10000, 2)

# %%
plt.plot(X_Data[:,0], X_Data[:,1], 'x')
# plt.axis('equal')
# plt.show()
# print(x.shape)
# print(y.shape)

# %%
print(np.array(np.linspace(0, 2, 3)).astype(int) )
# Out:
# [0 1 2]
